# %% [markdown]
# # Predicting Covid-19 Survival Based on Patient Demographics

# %% [markdown]
# # Introduction and Questions:
#
# In this workshop, we will analyze and explore a very insightful covid-19 dataset.
#
# The goal of this data science mini-project is to predict the survival of the patients' based on their democraphics and health status.
#
# Covid-19 being a fairly recent virus, any insights would be helful to understand potential disease risk and causes. Using Data science tools and algorithms could be used in assessing the safety and quality of care provided based on the patient's risk assessment.
#
# Therefore, we will try to understand if there is a correlation between COVID-19 survival/death and the some variables describing the patients such as gender, age, ethnicity, etc.
# Also we will explore the current trends of the death variable.
#
#  **Yet, our main question is the following: Can we predict a patients' mortality/survival**

# %% [markdown]
# ## Content
#
# In this workshop we will explore the following parts:
#
# 1. [Data Collection](#Data-Collection)
# 2. [Data Cleaning](#Data-Cleaning)
# 3. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# 4. [Modeling](#Modeling)

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import preprocessing 
import missingno as msno

# %% [markdown]
# # Part1.  Data Collection
#
# The <a href="https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data/vbim-akqf"> dataset </a>  we are working with is provided from <a href="https://www.cdc.gov">Centers for Disease Control and Prevention</a>. This organization runs a COVID-19 case surveillance system database that is based in the US.
#
# CDC have worked on developing technology to help ensure that disease reporting systems are integrated in US states.
# This reporting system initiated this rich dataset that includes individual-level data reported of confirmed and probable cases of COVID-19. The dataset consist of 8 columns labelled as:
#
# - **case_status**: Laboratory-confirmed case; Probable case
# - **sex**: Male; Female; Unknown; Other
# - **age_group**: 0 - 9 Years; 10 - 19 Years; 20 - 39 Years; 40 - 49 Years; 50 - 59 Years; 60 - 69 Years; 70 - 79     Years; 80 + Years
# - **Race and ethnicity**: Hispanic/Latino; American Indian / Alaska Native, Non-Hispanic; Asian, Non-Hispanic; Black, Non-Hispanic; Native Hawaiian / Other Pacific Islander, Non-Hispanic; White, Non-Hispanic; Multiple/Other, Non-Hispanic
# - **medcond_yn**: Presence of underlying comorbidity or disease
# - **hosp_yn**: Hospitalization status
# - **icu_yn**: ICU admission status (intensive care unit)
# - **death_yn**: Death status

# %% [markdown]
# ## 1. Run the cell below to load and read the dataset

# %%
data = pd.read_csv("https://github.com/ladyhodhod/Ibtikar21_DS/blob/main/COVID-19_Case_Surveillance_Public_Use_Data_mini.csv.zip?raw=true",compression='zip')

# %%
data.sample(3)
# Out:
#        cdc_case_earliest_dt              current_status     sex  \
# 791491            2020/05/06  Laboratory-confirmed case  Female
# 956641            2020/05/06  Laboratory-confirmed case  Female
# 764101            2020/03/27  Laboratory-confirmed case    Male
#
#             age_group race_ethnicity_combined  hosp_yn   icu_yn death_yn  \
# 791491  50 - 59 Years         Hispanic/Latino       No       No       No
# 956641  60 - 69 Years         Hispanic/Latino  Missing  Missing  Missing
# 764101  50 - 59 Years     White, Non-Hispanic       No       No       No
#
#        medcond_yn
# 791491         No
# 956641        Yes
# 764101        Yes

# %%
print ("The original dataset contains:", "{:,}".format(data.shape[0]), "examples")
# Out:
# The original dataset contains: 1,912,328 examples

# %% [markdown]
# # Part 2. Data Cleaning
#
# In its original full version, this dataset had 5 million entries of data with lots of missing values. Given the huge dataset, we had the flexibility to eliminate all rows with missing data. We will also dropped some other details like dates to make the case simpler.

# %% [markdown]
# ### Exercise: Run the following cell to check if there is any missing values for each variable in the dataset!
#
# ### What do you observe? Discuss your observation with your teammates.

# %%
msno.matrix(data)

# %% [markdown]
# This visual summary shows that there is not much of missing values for each of the variables we are studying.
# Let's explore this further!

# %% [markdown]
# We start with the variable `sex`, In the following cell, we will count the number of unique values in the column `sex`. Basically we would like to check if there are cases for which the sex was missing, and a value different than Null was assigned instead.

# %%
pd.DataFrame(data.sex.value_counts())
# Out:
#              sex
# Female   1012053
# Male      886857
# Unknown    10659
# Missing     2683
# Other         76

# %% [markdown]
# ### Exercise: Explore the missing values for the variable `race_ethnicity`.

# %%
### Write your code here!

# %% [markdown]
# Let's visualize each of them!

# %%
search_values= ['Missing', 'Unknown']
Missingdata=data[data.sex.str.contains('|'.join(search_values ))]

# %%
Missingdata.sample(10)
# Out:
#                        case_status      sex      age_group  \
# 1432732  Laboratory-confirmed case  Missing    0 - 9 Years
# 70988                Probable Case  Unknown  20 - 29 Years
# 1345826  Laboratory-confirmed case  Unknown  50 - 59 Years
# 1786523  Laboratory-confirmed case  Unknown  40 - 49 Years
# 1632892              Probable Case  Missing  20 - 29 Years
# 1682881  Laboratory-confirmed case  Unknown  30 - 39 Years
# 814775   Laboratory-confirmed case  Unknown  50 - 59 Years
# 1500804  Laboratory-confirmed case  Unknown  20 - 29 Years
# 680641   Laboratory-confirmed case  Unknown  50 - 59 Years
# 314656   Laboratory-confirmed case  Unknown  30 - 39 Years
#
#               race_ethnicity hospitalized      icu    death  medcond
# 1432732      Hispanic/Latino           No  Missing       No       No
# 70988        Hispanic/Latino      Missing  Missing  Missing  Unknown
# 1345826              Unknown           No  Missing  Missing  Missing
# ...

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.countplot(Missingdata['sex'])

# %%
sns.countplot(data['race_ethnicity'])

# %% [markdown]
# These distributions of variables with missing data shows us that a huge portion of patients didn't have their ethnicity/race logged in. Similarly with the death varible, a lot of the entries did not have the death variable logged in.

# %% [markdown]
# ### Let's check the `death` variable. Run the cell below to generate the distribution of death vs. non death in the recorded cases. What do you observe? How many COVID-19 affected patients survived? How many of them passed away?

# %%
sns.countplot(data['death'])

# %% [markdown]
# ### What do you think is the effect of missing data on the analysis? What would be a good strategy to fix this issue?

# %% [markdown]
# In Data Science, missing data poses a serious challenge to the whole study. Hence, However, for the sake of practicality, we follow the most basic strategy to clean the data from Missing values: Dropping them all.

# %% [markdown]
# - **Strategy 1**: Dropping all missing data (very dangerous decision, as we might end up with a very small dataset)
# Run the following cell to drop all the examples where any of the variables have a value of `Missing` or `Unkown`.
#
#     We store the result in a new data that we call `clean_data`

# %%
todrop= ['Missing', 'Unknown']

clean_data = data[~data['age_group'].isin(todrop) & ~data['sex'].isin(todrop) & ~data['race_ethnicity'].isin(todrop) & ~data['hospitalized'].isin(todrop) & ~data['icu'].isin(todrop) & ~data['death'].isin(todrop) & ~data['medcond'].isin(todrop)]
clean_data.sample(5)
# Out:
#                        case_status     sex      age_group  \
# 1390239  Laboratory-confirmed case    Male  50 - 59 Years
# 996861   Laboratory-confirmed case  Female  40 - 49 Years
# 1328149  Laboratory-confirmed case  Female  50 - 59 Years
# 507650   Laboratory-confirmed case    Male  20 - 29 Years
# 1185783  Laboratory-confirmed case    Male  10 - 19 Years
#
#               race_ethnicity hospitalized icu death medcond
# 1390239  White, Non-Hispanic           No  No    No      No
# 996861       Hispanic/Latino           No  No    No     Yes
# 1328149  White, Non-Hispanic           No  No    No      No
# 507650   White, Non-Hispanic           No  No    No      No
# 1185783  White, Non-Hispanic           No  No    No     Yes

# %% [markdown]
# # Part 3. Exploratory Data Analysis
#
# In this section, we will explore the trends and correlations of the variables against the death variable. We will first look at the distributions of our variables. Since all the variables are categorical, we will create bar charts.

# %% [markdown]
# ### Let's plot again the death vs. survival distribution. What do you observe?

# %%
sns.countplot(clean_data['death'])

# %% [markdown]
# To get the specific value counts representing the number of examples in each class (death vs. no death), run the following cell.

# %%
#final number of true cases
clean_data.death.value_counts()
# Out:
# No     346783
# Yes     15349
# Name: death, dtype: int64

# %% [markdown]
# ### It is your turn: Using a bar plot (just like we did for the death variable), explore the distribution of cases per age_group.

# %%
# write your code here.

# %% [markdown]
# ### To obtain the count of examples for each variable, run the code in the cell below.

# %%
# distributions by variable
categorical = [
  'case_status', 'age_group', 'sex', 'race_ethnicity', 'hospitalized', 'icu', 'death', 'medcond'
]
fig, ax = plt.subplots(4,2, figsize=(27, 50))
for variable, subplot in zip(categorical, ax.flatten()):
    sns.countplot(clean_data[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# ### What do you observe? Discuss this with your teammates.

# %% [markdown]
# Throughout the analysis of the distributions we can make few observations:
#
# - Most of the registered covid cases are of people of age  20-29.
# - A huge amount of the registered cases are people of the race white.
# - Approxiametly, at least 6% of the registered patients are dead.
# - There are more cases of females than males in this dataset.

# %% [markdown]
# ### Exploring each of the  variables against the death variable
#
# The following cell, contains code that will generate a diagram showing the age categories Survival distribution.

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.countplot(x = 'age_group',  data = clean_data, hue = 'death', palette = 'Set1')

ax.set(xlabel='Age Categories', ylabel='Total',
       title="Age Categories Survival Distribution")

plt.show()

# %% [markdown]
# ### It is your turn: copy the code from the cell above, and generate the survival distribution per gender (think of using the `sex` variable instead of `age_group`.

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.countplot(x = 'sex',  data = clean_data, hue = 'death', palette = 'Set1')

ax.set(xlabel='gender', ylabel='Total',
       title="Survival Distribution Based on Gender")

plt.show()

# %% [markdown]
# ### It is your turn: copy the code from the cell above, and generate the survival distribution per race and ethnicity.

# %%
sns.set(rc={'figure.figsize':(30,10)})
ax = sns.countplot(x = 'race_ethnicity',  data = data, hue = 'death_yn', palette = 'Set1')

ax.set(xlabel='Ethnicity and Race', ylabel='Total',
       title="Survival Distribution Based on Ethnicity")

plt.show()

# %% [markdown]
# ### It is your turn: copy the code from the cell above, and generate the survival distribution per medical condition.

# %%
sns.set(rc={'figure.figsize':(30,10)})
ax = sns.countplot(x = 'medcond',  data = clean_data, hue = 'death', palette = 'Set2')

ax.set(xlabel='Medical Condition', ylabel='Total',
       title="Survival Distribution Based on Medical Condition")

plt.show()

# %% [markdown]
# ### What do you observe? what does this mean? To understand the data, as a data sicentist, you should be able to explain diagrams.

# %% [markdown]
# Based on the graphs above, we can make the following points:
#
# - Patients that are older than 80 had the highest number of deaths
# - Males had more deaths than female even though the total number of female patients was greater
# - Patients of the white race had the highest cases of death, but that is because they were the most represented in this dataset
# - Almost all of the dead patients had an underlying comorbid diseases

# %% [markdown]
# ### Correlation between variables
# - Define what a correlation plot is? its importance in data science? when to use a correlation plot? Example: scatter plot! how do you describe the relationship between the two features?
# - Difference between correlation and causality: the ice cream and sunglasses case! Apply on our example.
#
# To plot the correlation between the variables, run the cell below. It will generate a HeatMap plot showing the intensity of the pairwise correlation between the variables we are exploring.
#
# Focus on the correlation between the `death` variable and the rest of the variables. What do you observe? Interpret the results.

# %%
data3=data
data3.sex.replace(('Female','Male', 'Other'), (0,1,2), inplace = True)
data3.current_status.replace(('Laboratory-confirmed case','Probable Case'), (0,1), inplace = True)
data3.age_group.replace(('0 - 9 Years','10 - 19 Years','20 - 29 Years','30 - 39 Years','40 - 49 Years','50 - 59 Years','60 - 69 Years','70 - 79 Years','80+ Years'), (0,1,2,3,4,5,6,7,8), inplace = True)
data3['Race and ethnicity (combined)'].replace(('American Indian/Alaska Native, Non-Hispanic','Asian, Non-Hispanic','Black, Non-Hispanic','Hispanic/Latino','Multiple/Other, Non-Hispanic','Native Hawaiian/Other Pacific Islander, Non-Hispanic','White, Non-Hispanic'), (0,1,2,3,4,5,6), inplace = True)
data3.hosp_yn.replace(('No','Yes'), (0,1), inplace = True)
data3.icu_yn.replace(('No','Yes'), (0,1), inplace = True)
data3.death_yn.replace(('No','Yes'), (0,1), inplace = True)
data3.medcond_yn.replace(('No','Yes'), (0,1), inplace = True)

plt.figure(figsize=(30,30))
sns.heatmap(data3.astype(float).corr(),linewidths=0.1, 
            square=True,  linecolor='white', annot=True)
plt.show()

# %% [markdown]
# From the correlation heat map, we focused on the death variable which had the highest correlations with the intensive care unit, hospitalization and gender variables. This makes since because icu and hospitalization means that the patient was in a critical condition. From this analysis, we identified the importance of some features that we we will emphasize in our training modeling.

# %% [markdown]
# # Part 4. Modeling

# %%
d = pd.get_dummies(clean_data, columns =['case_status', 'sex', 'age_group', 'race_ethnicity', 'hospitalized', 'icu', 'medcond'])

labels = np.array(np.where(d.death.values == 'Yes', 1, 0))
features = d.drop(['death'], axis = 1)
feature_list = list(features.columns)
features = np.array(features)

train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.1, random_state = 42)

Standardisation = preprocessing.StandardScaler() 
train_features = Standardisation.fit_transform(train_features) 

logisticRegr = LogisticRegression()
logisticRegr.fit(train_features, train_labels) 

pred_lr = logisticRegr.predict(test_features)

logisticRegr.score(test_features, test_labels)
# Out:
# 0.9579996686364389

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We hope this work inspires future research in predicting deaths, not only for Covid-19 but for other critical diseases as well. As much as the data and the feature importance results were insightful, it would have been interesting to know which specific medical conditions influence death cases. Unfortunately much data was not made public. Likewise, it would have been more accurate if the original data contained a bigger proportion of true cases. The limitation of imbalanced data should be taken into account when doing future work with this project. Nonetheless, we believe this project has important real-life implications. Such a project can help improve patient risk assessments and provide better assessment of the quality of care provided by the clinic or hospital.
